# %% [markdown]
# # Smart City Public Transit Delay Forecasting
# Supervised ML project for classifying the expected delay level of a public-transit trip in urban and rural settings.

# %%
import pandas as pd
df = pd.read_csv('../data/demo_transit_delay.csv')
df.head()

# %%
df.info()
df['delay_category'].value_counts()

# %%
# Run the training script from the project root:
# !python ../src/train_model.py

# %% [markdown]
# ## Important data note
# The included CSV is synthetic demo data. For a final research-grade run, replace it with a public GTFS/GTFS-Realtime-derived dataset and document the exact source and extraction date.
